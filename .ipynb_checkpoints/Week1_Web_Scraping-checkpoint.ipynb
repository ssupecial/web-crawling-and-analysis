# %% [markdown]
# # Software Coaching for Python
# # Week 1: Web Scraping

# %% [markdown]
# Instructor: Kang-Pyo Lee

# %%
from google.colab import drive

drive.mount('/content/gdrive')
path = "/content/gdrive/Shareddrives/SW_Coaching_for_Python"
my_folder = "ESK"     # *** REPLACE WITH YOUR FOLDER NAME ***
# Out:
# Mounted at /content/gdrive

# %%
! pip install --user requests bs4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)

# %% [markdown]
# ## Fetch HTML content from a webpage using Requests

# %% [markdown]
# https://fivethirtyeight.com/features/why-was-the-national-polling-environment-so-off-in-2020/

# %%
url = "https://fivethirtyeight.com/features/why-was-the-national-polling-environment-so-off-in-2020/"

# %% [markdown]
# *** Run the cells for HTTP requests only when needed.

# %%
import requests

r = requests.get(url)

# %% [markdown]
# https://requests.kennethreitz.org/

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US" class="no-js">\n<head>\n\t<meta charset="UTF-8">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\t\t<script src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js"></script>\n\t<title>Why Was The National Polling Environment So Off In 2020? | FiveThirtyEight</title>\n<!-- Jetpack Site Verification Tags -->\n\t\t\t\t\t<link\n\t\t\trel="preload"\n\t\t\tas="font"\n\t\t\ttype="font/woff2"\n\t\t\thref="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/fonts/AtlasGrotesk-Bold-Web.woff2"\n\t\t\tcrossorigin="anonymous">\n\t\t\t\t\t<link\n\t\t\trel="preload"\n\t\t\tas="font"\n\t\t\ttype="font/woff2"\n\t\t\thref="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/fonts/AtlasGrotesk-Regular-Web.woff2"\n\t\t\tcrossorigin="anonymous">\n\t\t\t\t\t<link\n\t\t\trel="preload"\n\t\t\tas="font"\n\t\t\ttype="font/woff2"\n\t\t\thref="https://fivethirtyeight.com/wp-content/themes/espn-fivethirtyeight/assets/fonts/decimamonopro-webfont.woff2"\n\t\t\tcrossorigin="anonymous">\n\t\t\t\t<link rel=\'dns-prefetch\' href=\'//cdn.registerdisney.go.com\' />\n<link rel=\'dns-prefetch\' href=\'//platform.twitter.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel=\'dns-prefetch\' href=\'//pagead2.googlesyndication.com\' />\n<link rel=\'dns-prefetch\' href=\'//tpc.googlesyndication.com\' />\n<link rel=\'dns-prefetch\' href=\'//securepubads.g.doubleclick.net\' />\n<link rel=\'dns-prefetch\' href=\'//www.googletagmanager.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.googletagservices.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.googleadservices.com\' />\n<link rel=\'dns-prefetch\' href=\'//adservice.google.com\' />\n<link rel=\'dns-prefetch\' href=\'//www.google.com\' />\n<link rel=\'stylesheet\' id=\'all-css-0\' href=\'https://fivethirtyeight.com/_static/??-eJxtzV0KwjAQBOALma5F/OmDeJYk3baL223Ibiu5vQERpPg8M9/AKzmSyGuPClEVelKDwEt8OqaQfS6gVhibmaSphQPURVzEUAwSryOJwkiDS+yLC6vZIuBV0T7eLvrL2IRzvUdN4gba0CbKVpDGyX6pXfSlHvO9vbTX7njqzrc3MQlNtg==\' type=\'text/css\' media=\'all\' />\n<style id=\'wp-block-library-inline-css\'>\n.has-text-align-justify{text-align:justify;}\n</style>\n<script id=\'disney-oneid-js-extra\'>\nvar DisneyOneID = {"config":{"clientId":"DATG-FIVETHIRTYEIGHT.WEB-PROD","langPref":"en-US","debug":false,"responderPage":"https:\\/\\/fivethirtyeight.com\\/oneid-responder","campaignName":"FiveThirtyEight"}};\n</script>\n<script src=\'https://cdn.registerdisney.go.com/v2/outer/DisneyID.js?clientID=DATG-FIVETHIRTYEIGHT.WEB-PROD\' id=\'disney-oneid-js\'></script>\n<script id=\'taboola-js-extra\'>\nvar ESPNTaboola = {"publisher":"abcnews-fivethirtyeight","type":"article"};\n</script>\n<script type=\'text/javascript\' src=\'https://fivethirtyeight.com/_static/??-\'></script>\n<script async="async" defer="defer" src=\'https://platform.twitter.com/widgets.js?ver=1.0.24\' id=\'platform-twitter-js\'></script>\n<script id=\'abc-analytics-js-extra\'>\nvar ABCAnalytics = {"nielsen":{"asset_id":304660,"section":"politics2020-election","seg_a":"","seg_b":"","seg_c":"","debug":""},"chartbeat":{"uid":"12240","domain":"fivethirtyeight.com","path":"\\/features\\/why-was-the-national-polling-environment-so-off-in-2020\\/","sections":"politics,features","authors":"Geoffrey Skelley","title":"Why Was The National Polling Environment So Off In 2020?","loadPubJS":false,"loadVidJS":true},"gtm":{"id":"GTM-KLHT6T2"},"omniture":{"pageName":"politics:features:why-was-the-national-polling-environment-so-off-in-2020","prop1":"fivethirtyeight","prop2":"","prop5":"features","prop6":"Geoffrey Skelley","prop7":"politics","prop8":"politics:2020-election","prop12": ...

# %% [markdown]
# Note that the HTML content you have retrieved does not always corresopond to what you are actually seeing on a web browser. Web sites are able to distinguish program access from normal human access using a web browser. Some web sites do not care about the program access, whereas other web sites do care about it and block the undesirable access. In this case, take a close look at the HTML content and you will see it does not have the information you expected.

# %% [markdown]
# ## Load the fetched content as a BeautifulSoup object

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.content, "html.parser")

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ## Extract the title of the webpage

# %% [markdown]
# Do not confuse the title of a webpage with the title of an article.

# %%
soup.title
# Out:
# <title>Why Was The National Polling Environment So Off In 2020? | FiveThirtyEight</title>

# %%
soup.title.text
# Out:
# 'Why Was The National Polling Environment So Off In 2020? | FiveThirtyEight'

# %% [markdown]
# ## Extract the title of the article

# %% [markdown]
# If you want to extract information from a webpage, always start by identifying the corresponding HTML element in the HTML code using the Inspect feature of the Chrome Browser.
#
# When searching for an HTML element using <b>BeautifulSoup</b>, you can use either the <b>find</b> method or <b>find_all</b> method.
# - The <b>find</b> method returns the first found element.
# - The <b>find_all</b> method returns a list of all found elements in order.
#
# You can simply choose to use the <b>find</b> mehtod if you are confident that there is only one element matching or the element you are searching for is the first element matching.

# %%
soup.find(name="h1", attrs={"class": "article-title article-title-single entry-title"})
# Out:
# <h1 class="article-title article-title-single entry-title">
# 									Why Was The National Polling Environment So Off In 2020?								</h1>

# %%
soup.find(name="h1")
# Out:
# <h1 class="article-title article-title-single entry-title">
# 									Why Was The National Polling Environment So Off In 2020?								</h1>

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find

# %% [markdown]
# In addition to specifying the tag of the element you are searching for in the first parameter `name`, you can use any clues that help identify the element by specifying them in the second parameter `attrs`. Note the `attrs` parameter takes a dictionary.
#
# In the above example, if the class name is unique, you will always be able to find the element. If not, the <b>find</b> method will return the first found element, which could not be the element you are trying to find. In this case, you would better use different clues in the `attrs` parameter or consider using the <b>find_all</b> method.

# %%
soup.find("h1", {"class": "article-title article-title-single entry-title"}).text
# Out:
# '\n\t\t\t\t\t\t\t\t\tWhy Was The National Polling Environment So Off In 2020?\t\t\t\t\t\t\t\t'

# %%
soup.find("h1", {"class": "article-title article-title-single entry-title"}).text.strip()
# Out:
# 'Why Was The National Polling Environment So Off In 2020?'

# %% [markdown]
# ## Extract the author name of the article

# %%
soup.find("a", {"class": "author url fn"})
# Out:
# <a class="author url fn" href="https://fivethirtyeight.com/contributors/geoffrey-skelley/" rel="author" title="">Geoffrey Skelley</a>

# %%
soup.find("a", {"class": "author url fn"}).text
# Out:
# 'Geoffrey Skelley'

# %%
soup.find("a", {"class": "author url fn"})["href"]
# Out:
# 'https://fivethirtyeight.com/contributors/geoffrey-skelley/'

# %% [markdown]
# ## Fetch an image from the webpage

# %% [markdown]
# 마땅히 구별할 정보가 없을 때 parent, ancestor 속성을 이용하면 됨.

# %%
soup.find("picture", {"class": "featured-picture"})
# Out:
# <picture class="featured-picture">
# <source media="(min-width: 768px)" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=1150 2x"/>
# <source srcset="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=1150 2x"/>
# <img alt="GENERIC-BALLOT-0222-4×3" class="" sizes="(max-width: 768px) 100vw, (max-width: 1080px) 66vw, 684px" src="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=1150 2x"/>
# </picture>

# %% [markdown]
# When the element you are searching for has no unique clues, you should try finding the parent/ancestor element, by which you can narrow down the scope of search, and then you can start another search from there. This is the beauty of hierarchical search.

# %%
soup.find("picture", {"class": "featured-picture"}).find("img")
# Out:
# <img alt="GENERIC-BALLOT-0222-4×3" class="" sizes="(max-width: 768px) 100vw, (max-width: 1080px) 66vw, 684px" src="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575" srcset="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575 1x, https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=1150 2x"/>

# %% [markdown]
# Because there is only one img element in the picture element found above, you do not have to add any additional attributes, or clues, in the find method.

# %%
soup.find("picture", {"class": "featured-picture"}).find("img")["src"]
# Out:
# 'https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575'

# %%
img_url = soup.find("picture", {"class": "featured-picture"}).find("img")["src"]
img_url
# Out:
# 'https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575'

# %%
from IPython.display import Image

Image(url=img_url)
# Out:
# <img src="https://fivethirtyeight.com/wp-content/uploads/2021/02/GENERIC-BALLOT-0222-4x3-1.png?w=575"/>

# %% [markdown]
# Note that this is not saving the image. It is just displaying the image fetched from the website.

# %%
outcome_folder = "{}/{}/outcome".format(path, my_folder)
outcome_folder
# Out:
# '/content/gdrive/Shareddrives/SW_Coaching_for_Python/ESK/outcome'

# %%
import os

if not os.path.isdir(outcome_folder):         # Check if there is an existing directory named outcome.
    os.mkdir(outcome_folder)                  # Create a new directory named data.

# %% [markdown]
# The <b>os.mkdir</b>(path) function creates a directory named `path`.

# %% [markdown]
# We are going to save all of our outcome files in the `outcome` directory.

# %%
r = requests.get(img_url)

with open("{}/photo.jpg".format(outcome_folder), "w+b") as fw:
    fw.write(r.content) #r.content == 이미지 데이터

# %%
Image("{}/photo.jpg".format(outcome_folder))

# %% [markdown]
# ## Extract the body text of the article

# %%
soup.find("div", attrs={"class": "entry-content single-post-content"})
# Out:
# <div class="entry-content single-post-content">
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">
#
# <html><body><p>Heading into the 2020 election, Democrats were favored to not only <a href="https://projects.fivethirtyeight.com/2020-election-forecast/">capture the presidency</a> but also <a href="https://projects.fivethirtyeight.com/2020-election-forecast/senate/">win back the Senate</a> and retain their <a href="https://projects.fivethirtyeight.com/2020-election-forecast/house/">sizable majority in the House</a>. Much of that came down to the overall national environment, which appeared to be pretty favorable to Democrats, as they held a 7.3-point lead in <a href="https://projects.fivethirtyeight.com/congress-generic-ballot-polls/">FiveThirtyEight’s final polling average of congressional polls</a>.</p>
# <p>Yet even though Democrats did win the presidency — and <a href="https://fivethirtyeight.com/features/how-democrats-won-the-georgia-runoffs/">eventually the Senate</a> — their grip on the House actually slipped, <a href="https://fivethirtyeight.com/features/republicans-2020-gains-in-the-house-set-them-up-well-for-2022/">as Republican gains</a> meant the Democrats’ majority fell from a 32-seat advantage<a class="espn-footnote-link" data-footnote-content="&lt;p&gt;&lt;p&gt;If a seat was vacant, we marked party control by whichever party previously held the seat.&lt;/p&gt;
# &lt;/p&gt;" data-footnote-id="1" href="#fn-1"><sup id="ss-1">1</sup></a> to just a 9-seat edge after the election.<br/><br/></p>
# <div class="ornamental-rule">
# <hr/><p><span></span></p></div>
# <h3 class="video-title">How the Georgia runoffs changed the ‘polling is broken’ narrative</h3>
# <div class="video-placeholder videoplayer abc"><iframe allow="fullscreen" class="abc-player" data-omniture="video-on-storypage|304660|Why Was The National Polling Environment So Off In 2020?|75548598" height="100%" scrolling="no" src="https://fivethirtyeight.abcnews.go.com/video/embed/75548598?section=politics" width="100%"></iframe></div>
# <div class="video-footer">
# <div class="video-footer-links"><a href="/videos/">All Videos</a><a href="https://www.youtube.com/FiveThirtyEight" target="_blank">YouTube</a></div>
# <hr/></div>
# <p></p>
# <div class="ad-incontentteads" data-defer="none" id="ad-incontentTeads"></div><p>So what happened? Were the polls just terribly off in 2020? <a href="https://fivethirtyeight.com/features/the-polls-werent-great-but-thats-pretty-normal/">Not dramatically</a>, no. Yes, polls once again <a href="https://fivethirtyeight.com/features/the-polls-are-all-right/">underestimated Donald Trump’s performance</a>, but the magnitude of that error (about 4 percentage points) wasn’t all that different from past presidential contests, such as in 2012 when polls underestimated Barack Obama’s margin of victory by almost 4 points. And there have, of course, been much larger polling errors, too.</p>
# <p><a href="https://fivethirtyeight.com/features/where-did-all-the-bellwether-counties-go/?cid=_inlinerelated"><em><strong>[Where Did All The Bellwether Counties Go?]</strong></em></a></p>
# <p>But one reason the polling in 2020 has received so much attention is that down-ballot polling, namely the generic ballot — which asks respondents whether they plan to vote for a Democrat or Republican in their local race for the U.S. House of Representatives — was also off by a similarly large margin in 2020. In fact, as the table below shows, the House popular vote was 4.2 points more Republican-leaning than the polls anticipated, making it the largest generic ballot polling miss in a presidential or midterm cycle since 2006.<a class="espn-footnote-link" data-footnote-content="&lt;p&gt;&lt;p&gt;Prior to 1996, there wasn’t enough polling comparatively speaking to retroactively calculate averages using FiveThirtyEight’s polling-average methodology.&lt;/p&gt;
# &lt;/p&gt;" data-footnote-id="2" href="#fn-2"><sup id="ss-2">2</sup></a></p>
# <section class="viz"><header class="viz"><h5 class="title">The generic ballot was off significantly in 2020</h5>
# <p class="subtitle">FiveThirtyEight’s historical generic ballot polling average on Election Day vs. the actual national popular vote for the U.S. House of Representatives, 1996 to 2020</p>
# </header><table class="viz full" data-carpenter-slug="skelley.generic-ballot.1"><thead><tr><th class="upper" colspan="1" style="border-right: 10px solid #ffffff"></th>
# <th class="upper upper-text" colspan="2" style="border-right: 10px solid #ffffff">National House vote margin</th>
# <th class="upper" colspan="1"></th>
# </tr><tr><th class="no-parent text" colspan="1" style="width: 10%;text-align: left">Year</th>
# <th class="number" colspan="1" style="font-weight: 400;width: 32%">Poll Avg.</th>
# <th class="number" colspan="1" style="font-weight: 400;width: 32%">Actual result</th>
# <th class="no-parent number" colspan="1" style="width: 24%">Error</th>
# </tr></thead><tbody><tr><td class="text" style="width: 10%;text-align: left">2020</td>
# <td class="number" style="width: 32%;color: #008fd5">D+7.3</td>
# <td class="number" style="width: 32%;color: #008fd5">D+3.1</td>
# <td class="number highlight" style="width: 24%">4.2</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2018</td>
# <td class="number" style="width: 32%;color: #008fd5">D+8.6</td>
# <td class="number" style="width: 32%;color: #008fd5">D+8.6</td>
# <td class="number highlight" style="width: 24%">0.0</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2016</td>
# <td class="number" style="width: 32%;color: #008fd5">D+1.3</td>
# <td class="number" style="width: 32%;color: #ff2700">R+1.0</td>
# <td class="number highlight" style="width: 24%">2.4</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2014</td>
# <td class="number" style="width: 32%;color: #ff2700">R+1.9</td>
# <td class="number" style="width: 32%;color: #ff2700">R+5.8</td>
# <td class="number highlight" style="width: 24%">3.9</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2012</td>
# <td class="number" style="width: 32%;color: #008fd5">D+2.5</td>
# <td class="number" style="width: 32%;color: #008fd5">D+1.3</td>
# <td class="number highlight" style="width: 24%">1.2</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2010</td>
# <td class="number" style="width: 32%;color: #ff2700">R+6.7</td>
# <td class="number" style="width: 32%;color: #ff2700">R+6.6</td>
# <td class="number highlight" style="width: 24%">0.1</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2008</td>
# <td class="number" style="width: 32%;color: #008fd5">D+8.8</td>
# <td class="number" style="width: 32%;color: #008fd5">D+10.6</td>
# <td class="number highlight" style="width: 24%">1.8</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2006</td>
# <td class="number" style="width: 32%;color: #008fd5">D+13.9</td>
# <td class="number" style="width: 32%;color: #008fd5">D+7.9</td>
# <td class="number highlight" style="width: 24%">6.0</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2004</td>
# <td class="number" style="width: 32%;color: #008fd5">D+1.2</td>
# <td class="number" style="width: 32%;color: #ff2700">R+2.6</td>
# <td class="number highlight" style="width: 24%">3.9</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2002</td>
# <td class="number" style="width: 32%;color: #ff2700">R+0.2</td>
# <td class="number" style="width: 32%;color: #ff2700">R+4.6</td>
# <td class="number highlight" style="width: 24%">4.4</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">2000</td>
# <td class="number" style="width: 32%;color: #008fd5">D+3.2</td>
# <td class="number" style="width: 32%;color: #ff2700">R+0.3</td>
# <td class="number highlight" style="width: 24%">3.6</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left">1998</td>
# <td class="number" style="width: 32%;color: #ff2700">R+0.2</td>
# <td class="number" style="width: 32%;color: #ff2700">R+0.9</td>
# <td class="number highlight" style="width: 24%">0.7</td>
# </tr><tr><td class="text" style="width: 10%;text-align: left;border-bottom: 1px solid #222222">1996</td>
# <td class="number" style="width: 32%;color: #008fd5;border-bottom: 1px solid #222222">D+5.4</td>
# <td class="number" style="width: 32%;color: #008fd5;border-bottom: 1px solid #222222">D+0.3</td>
# <td class="number highlight" style="width: 24%;border-bottom: 1px solid #222222">5.1</td>
# </tr><tr><td class="text bold" style="width: 10%;text-align: left;background-color: #ffffff">Average</td>
# <td class="number bold" style="width: 32%;background-color: #ffffff"></td>
# <td class="number bold" style="width: 32%;background-color: #ffffff"></td>
# <td class="number highlight bold" style="width: 24%;background-color: #ffffff">2.9</td>
# </tr></tbody></table><footer class="viz"><p class="notes">FiveThirtyEight’s polling averages are calculated retroactively for years prior to 2018.</p>
# <p class="source">Sources: The Cook Political Report, Polls, U.S. House of Representatives</p>
# </footer></section><p>The fact that congressional polls performed so well just two years prior meant the error in 2020 <i>felt</i> particularly large, too. In 2018, the polls nailed the House popular vote right on the head, besting the 2010 midterms for the most accurate cycle in generic ballot polling dating back to 1996.</p>
# <p>That said, comparing the performance of generic ballot polls in 2020 to 2018 is a bit of a red herring as generic ballot polls are often a <a href="https://fivethirtyeight.com/features/our-best-tool-for-predicting-midterm-elections-works-in-presidential-years-too/">better predictor of midterm results</a> than presidential ones: The average error in presidential years was 3.1 points versus 2.5 points in midterms, according to FiveThirtyEight’s polling average. But still, if we look at an average of generic ballot polls from 1996 to 2020 — covering seven presidential elections and six midterms — the polls were only off by 2.9 points. As such, the error in 2020 does rank on the higher end of the spectrum. Nonetheless, it was not the worst performing year for generic ballot polling in the past two and a half decades for which we have data. The polls missed by more in 1996, 2002 and 2006.</p>
# <p><a href="https://fivethirtyeight.com/features/why-only-16-districts-voted-for-a-republican-and-a-democrat-in-2020/?cid=_inlinerelated"><em><strong>[Why Only 16 Districts Voted For A Republican And A Democrat In 2020]</strong></em></a></p>
# <div class="ad-incontentteads2" data-defer="none" id="ad-incontentTeads2"></div><p>It’s hard to pinpoint why exactly the generic ballot polls were so off in 2020, but here are some possible explanations.</p>
# <p>First, it’s possible the 2020 generic ballot polling error was actually pretty normal — that is, generic ballot polls <a href="https://web.archive.org/web/20080830015140/http://www.pollster.com/blogs/generic_house_vs_national_vote.php">often underestimate GOP support</a>. In the past 13 election cycles, there has been just one time the House vote was clearly more Democratic than the final polling average (and three cases in which the polling error has been within plus/minus 1 point in either direction). Otherwise, the GOP has consistently performed better than the polls expected, in varying degrees, of course.</p>
# <p>But there are some conditions specific to 2020 that could have affected generic ballot polling, too. Notably, presidential polls also underestimated the Republican candidate, so it’s plausible that some of the same issues that <a href="https://www.newyorker.com/news/q-and-a/nate-cohn-explains-what-the-polls-got-wrong">influenced polling in the 2020 presidential race</a>, such as not enough Republicans responding to surveys, may have also altered generic ballot polling.<br/><br/></p>
# <div class="ornamental-rule">
# <hr/><p><span></span></p></div>
# <h3 class="video-title">Confidence Interval: Republicans Will Win Back Congress In 2022 | FiveThirtyEight</h3>
# <div class="video-placeholder videoplayer abc"><iframe allow="fullscreen" class="abc-player" data-omniture="video-on-storypage|304660|Why Was The National Polling Environment So Off In 2020?|76005297" height="100%" scrolling="no" src="https://fivethirtyeight.abcnews.go.com/video/embed/76005297?section=politics" width="100%"></iframe></div>
# <div class="video-footer">
# <div class="video-footer-links"><a href="/videos/">All Videos</a><a href="https://www.youtube.com/FiveThirtyEight" target="_blank">YouTube</a></div>
# <hr/></div>
# <p></p>
# <p>The 2020 election was also the first modern-day election <a href="https://fivethirtyeight.com/features/this-isnt-the-first-time-america-has-weathered-a-crisis-in-an-election-year/">held during a pandemic</a>, which could have affected polling — not to mention <a href="https://fivethirtyeight.com/features/how-much-did-covid-19-affect-the-2020-election/">the actual results</a>. In fact, COVID-19 may actually have caused <a href="https://www.vox.com/policy-and-politics/2020/11/10/21551766/election-polls-results-wrong-david-shor">Democrats to be overrepresented in some polls</a>, as the combination of being stuck at home and anti-Trump energy may have made them more likely to answer pollsters than Republicans. This, in turn, may have exacerbated <a href="https://www.pewresearch.org/methods/2017/05/15/what-low-response-rates-mean-for-telephone-surveys/">issues of non-response</a>, which can translate into pollsters missing GOP support. What’s more, people who feel <a href="https://www.wiley.com/en-us/Nonresponse+in+Household+Interview+Surveys-p-9780471182450">more alienated</a> and alone are often the ones who are <a href="https://www.nber.org/system/files/working_papers/t0328/t0328.pdf">less likely to respond to polls</a>, and in 2020, at least, they were also more likely to have <a href="https://fivethirtyeight.com/features/could-social-alienation-among-some-trump-supporters-help-explain-why-polls-underestimated-trump-again/">backed Trump and other Republican candidates</a>.</p>
# <p>Patrick Murray, director of the <a href="https://www.monmouth.edu/polling-institute/about/">Monmouth University Polling Institute</a>, told me he’s still in the process of understanding which voters aren’t responding to polls, but he thinks issues of non-response bias may be the likeliest culprit for polling error in 2020. Nailing down just how much of a role non-response bias played in that error won’t be easy, though. “If the error is due to non-response bias caused by a portion of the electorate that came out only to support Donald Trump, then the polls may be basically fine in 2022 and we really won’t know why,” said Murray. Remember, too, that the size and direction of polling error <a href="https://fivethirtyeight.com/features/weve-updated-our-pollster-ratings-ahead-of-the-2020-general-election/">has historically been unpredictable</a>, so we can’t just bank on Democratic bias being the new normal for pollsters to adjust to. That said, Murray did say this could all be a much bigger issue if the polls are “about 3 to 4 points more left-leaning in their responses because a skewed cohort of folks [have] tuned out from participating in traditional venues of political discourse.”</p>
# <p><a href="https://fivethirtyeight.com/features/nine-lessons-i-learned-about-political-reporting-while-covering-trump/?cid=_inlinerelated"><em><strong>[What The Trump Era Taught Me About Covering Politics]</strong></em></a></p>
# <p>At this point, we don’t know how widespread of an issue non-response in polling is. But one thing we do know is that what happened down-ballot in 2020 was at least partially tied up in the outcome of the presidential race, as Trump also outperformed his polls and most voters <a href="https://fivethirtyeight.com/features/there-wasnt-that-much-split-ticket-voting-in-2020/">voted for the same party</a> for president and the House. In fact, presidential and generic ballot polls have largely moved in the same direction: In total, in five of the seven presidential elections since 1996, the polling error in the presidential race has gone in the same direction as the error in the House contest (which was true in 2020 as well).</p>
# <section class="viz"><header class="viz"><h5 class="title">Poll error is often in the same direction</h5>
# <p class="subtitle">Polling error in presidential and generic ballot polling averages in presidential years, according to FiveThirtyEight’s averages, 1996 to 2020</p>
# </header><table class="viz full" data-carpenter-slug="skelley.generic-ballot.2"><thead><tr><th class="upper" colspan="1" style="border-right: 10px solid #ffffff"></th>
# <th class="upper upper-text" colspan="2" style="border-right: 10px solid #ffffff">Polling Error</th>
# <th class="upper" colspan="1"></th>
# </tr><tr><th class="no-parent text" colspan="1" style="width: 10%">Year</th>
# <th class="number" colspan="1" style="font-weight: 400;width: 32%">President</th>
# <th class="number" colspan="1" style="font-weight: 400;width: 32%">House</th>
# <th class="no-parent number" colspan="1" style="width: 24%">Gap</th>
# </tr></thead><tbody><tr><td class="text" style="width: 10%">2020</td>
# <td class="number" style="width: 32%;color: #ff2700">R+4.0</td>
# <td class="number" style="width: 32%;color: #ff2700">R+4.2</td>
# <td class="number" style="width: 24%">0.2</td>
# </tr><tr><td class="text" style="width: 10%">2016</td>
# <td class="number" style="width: 32%;color: #ff2700">R+1.9</td>
# <td class="number" style="width: 32%;color: #ff2700">R+2.4</td>
# <td class="number" style="width: 24%">0.5</td>
# </tr><tr><td class="text highlight" style="width: 10%">2012</td>
# <td class="number highlight" style="width: 32%;color: #008fd5">D+3.5</td>
# <td class="number highlight" style="width: 32%;color: #ff2700">R+1.2</td>
# <td class="number highlight" style="width: 24%">4.7</td>
# </tr><tr><td class="text" style="width: 10%">2008</td>
# <td class="number" style="width: 32%;color: #008fd5">D+0.1</td>
# <td class="number" style="width: 32%;color: #008fd5">D+1.8</td>
# <td class="number" style="width: 24%">1.7</td>
# </tr><tr><td class="text" style="width: 10%">2004</td>
# <td class="number" style="width: 32%;color: #ff2700">R+0.8</td>
# <td class="number" style="width: 32%;color: #ff2700">R+3.9</td>
# <td class="number" style="width: 24%">3.0</td>
# </tr><tr><td class="text highlight" style="width: 10%">2000</td>
# <td class="number highlight" style="width: 32%;color: #008fd5">D+4.1</td>
# <td class="number highlight" style="width: 32%;color: #ff2700">R+3.6</td>
# <td class="number highlight" style="width: 24%">7.7</td>
# </tr><tr><td class="text" style="width: 10%">1996</td>
# <td class="number" style="width: 32%;color: #ff2700">R+4.3</td>
# <td class="number" style="width: 32%;color: #ff2700">R+5.1</td>
# <td class="number" style="width: 24%">0.8</td>
# </tr></tbody></table><footer class="viz"><p class="notes">FiveThirtyEight’s polling averages are calculated retroactively for years prior to 2020.</p>
# <p class="source">Sources: Dave Leip’s Atlas of U.S. Presidential Elections, The Cook Political Report, Polls, U.S. House of Representatives</p>
# </footer></section><p>Robert Erikson, a political scientist at Columbia University <a href="https://polisci.columbia.edu/content/robert-s-erikson">who studies election polling</a>, told me it makes sense that we often see polling error in the same direction. “There’s a last-minute trend that the polls obviously can’t capture,” Erikson told me, and as 2020 showed, that usually means movement in the direction of the same party. “If Trump gained at the end, it only stands to reason that Republican candidates [down the ballot] would, too.” And it does seem as if there may have been some last-minute movement in the polls toward Trump in 2020. The <a href="https://www.cnn.com/election/2020/exit-polls/president/national-results">national exit poll found</a>, for instance, that Trump won more late-deciding voters than Biden (although we should be careful with that data considering so many voters <a href="https://fivethirtyeight.com/features/what-absentee-voting-looked-like-in-all-50-states/">cast early or absentee votes</a> in 2020).</p>
# <p>The difference in the error between presidential and generic ballot polls has typically been fairly small, too. There are only two presidential elections in the last 25 years in which the error went in different directions — 2000 and 2012 — and as such, those were the only two times that the difference between the two was particularly big. This is in large part because the errors are often related — either due to unforeseen environmental factors like a stronger-than-expected <a href="https://fivethirtyeight.com/features/how-much-trump-could-help-or-harm-down-ballot-republicans-in-november/">presidential performance</a> at the top of the ticket by one party or the reality that often the same pollsters who conduct national presidential polls are also the ones testing the generic ballot, meaning any of their <a href="https://fivethirtyeight.com/features/calculating-house-effects-of-polling-firms/">biases or methodological choices</a> in polling one race might carry over to the next.</p>
# <p><a href="https://fivethirtyeight.com/features/what-absentee-voting-looked-like-in-all-50-states/?cid=_inlinerelated"><em><strong>[What Absentee Voting Looked Like In All 50 States]</strong></em></a></p>
# <p>“Any non-response bias due to missing Trump support also impacted down-ballot measures — whether specific races or generic ballot,” Murray told me. He did caution, though, that our expectations of what polling can — and can’t — do probably need a reality check. That is, the value of the generic ballot is that it identifies trends, Murray stressed, not that it should be used to determine how an individual district might vote.</p>
# <p>“Being off by 3 to 4 points on a typical public opinion question is generally not consequential if the responses are in the ballpark,” said Murray. “Of course, being off by 3 to 4 points in an election poll is the end of the world.” But that, Murray told me, says less about the practice of polling than it does about the unrealistic expectations of what polling can do.</p>
# <p>And that serves as a good reminder that polls in general — including the generic ballot — are not <i>perfect</i> predictors, as FiveThirtyEight will tell you until the end of time. That’s why our forecasts build in <a href="https://fivethirtyeight.com/features/how-fivethirtyeights-2020-presidential-forecast-works-and-whats-different-because-of-covid-19/">plenty of room for uncertainty</a>. The generic ballot is helpful for getting a general sense of the electoral environment — does it lean toward one party or does it seem fairly competitive? But expecting it to routinely turn out to be as accurate as it was in, say, the 2018 midterms, is simply unrealistic.<br/><br/></p>
# <div class="ornamental-rule">
# <hr/><p><span></span></p></div>
# <h3 class="video-title">Senators voting to convict Trump haven’t ‘signed an electoral death warrant’: Silver</h3>
# <div class="video-placeholder videoplayer abc"><iframe allow="fullscreen" class="abc-player" data-omniture="video-on-storypage|304660|Why Was The National Polling Environment So Off In 2020?|76030419" height="100%" scrolling="no" src="https://fivethirtyeight.abcnews.go.com/video/embed/76030419?section=politics" width="100%"></iframe></div>
# <div class="video-footer">
# <div class="video-footer-links"><a href="/videos/">All Videos</a><a href="https://www.youtube.com/FiveThirtyEight" target="_blank">YouTube</a></div>
# <hr/></div>
# <p></p>
# <p><br/></p>
# <div class="ornamental-rule">
# <hr/><p><span></span></p></div>
# <h3 class="video-title">Democrats’ COVID relief bill is popular, but GOP may not vote for it</h3>
# <div class="video-placeholder videoplayer abc"><iframe allow="fullscreen" class="abc-player" data-omniture="video-on-storypage|304660|Why Was The National Polling Environment So Off In 2020?|76055259" height="100%" scrolling="no" src="https://fivethirtyeight.abcnews.go.com/video/embed/76055259?section=politics" width="100%"></iframe></div>
# <div class="video-footer">
# <div class="video-footer-links"><a href="/videos/">All Videos</a><a href="https://www.youtube.com/FiveThirtyEight" target="_blank">YouTube</a></div>
# <hr/></div>
# <p></p></body></html>
# </div>

# %%
soup.find("div", attrs={"class": "entry-content single-post-content"}).text
# Out:
# '\n\nHeading into the 2020 election, Democrats were favored to not only capture the presidency but also win back the Senate and retain their sizable majority in the House. Much of that came down to the overall national environment, which appeared to be pretty favorable to Democrats, as they held a 7.3-point lead in FiveThirtyEight’s final polling average of congressional polls.\nYet even though Democrats did win the presidency — and eventually the Senate — their grip on the House actually slipped, as Republican gains meant the Democrats’ majority fell from a 32-seat advantage1 to just a 9-seat edge after the election.\n\n\nHow the Georgia runoffs changed the ‘polling is broken’ narrative\n\n\nAll VideosYouTube\n\n\nSo what happened? Were the polls just terribly off in 2020? Not dramatically, no. Yes, polls once again underestimated Donald Trump’s performance, but the magnitude of that error (about 4 percentage points) wasn’t all that different from past presidential contests, such as in 2012 when polls underestimated Barack Obama’s margin of victory by almost 4 points. And there have, of course, been much larger polling errors, too.\n[Where Did All The Bellwether Counties Go?]\nBut one reason the polling in 2020 has received so much attention is that down-ballot polling, namely the generic ballot — which asks respondents whether they plan to vote for a Democrat or Republican in their local race for the U.S. House of Representatives — was also off by a similarly large margin in 2020. In fact, as the table below shows, the House popular vote was 4.2 points more Republican-leaning than the polls anticipated, making it the largest generic ballot polling miss in a presidential or midterm cycle since 2006.2\nThe generic ballot was off significantly in 2020\nFiveThirtyEight’s historical generic ballot polling average on Election Day vs. the actual national popular vote for the U.S. House of Representatives, 1996 to 2020\n\nNational House vote margin\n\nYear\nPoll Avg.\nActual result\nError\n2020\nD+7.3\nD+3.1\n4.2\n2018\nD+8.6\nD+8.6\n0.0\n2016\nD+1.3\nR+1.0\n2.4\n2014\nR+1.9\nR+5.8\n3.9\n2012\nD+2.5\nD+1.3\n1.2\n2010\nR+6.7\nR+6.6\n0.1\n2008\nD+8.8\nD+10.6\n1.8\n2006\nD+13.9\nD+7.9\n6.0\n2004\nD+1.2\nR+2.6\n3.9\n2002\nR+0.2\nR+4.6\n4.4\n2000\nD+3.2\nR+0.3\n3.6\n1998\nR+0.2\nR+0.9\n0.7\n1996\nD+5.4\nD+0.3\n5.1\nAverage\n\n\n2.9\nFiveThirtyEight’s polling averages are calculated retroactively for years prior to 2018.\nSources: The Cook Political Report, Polls, U.S. House of Representatives\nThe fact that congressional polls performed so well just two years prior meant the error in 2020 felt particularly large, too. In 2018, the polls nailed the House popular vote right on the head, besting the 2010 midterms for the most accurate cycle in generic ballot polling dating back to 1996.\nThat said, comparing the performance of generic ballot polls in 2020 to 2018 is a bit of a red herring as generic ballot polls are often a better predictor of midterm results than presidential ones: The average error in presidential years was 3.1 points versus 2.5 points in midterms, according to FiveThirtyEight’s polling average. But still, if we look at an average of generic ballot polls from 1996 to 2020 — covering seven presidential elections and six midterms — the polls were only off by 2.9 points. As such, the error in 2020 does rank on the higher end of the spectrum. Nonetheless, it was not the worst performing year for generic ballot polling in the past two and a half decades for which we have data. The polls missed by more in 1996, 2002 and 2006.\n[Why Only 16 Districts Voted For A Republican And A Democrat In 2020]\nIt’s hard to pinpoint why exactly the generic ballot polls were so off in 2020, but here are some possible explanations.\nFirst, it’s possible the 2020 generic ballot polling error was actually pretty normal — that is, generic ballot polls often underestimate GOP support. In the past 13 election cycles, there has been just one time the ...

# %%
soup.find("div", attrs={"class": "entry-content single-post-content"}).text.replace("\n", " ").strip()
# Out:
# 'Heading into the 2020 election, Democrats were favored to not only capture the presidency but also win back the Senate and retain their sizable majority in the House. Much of that came down to the overall national environment, which appeared to be pretty favorable to Democrats, as they held a 7.3-point lead in FiveThirtyEight’s final polling average of congressional polls. Yet even though Democrats did win the presidency — and eventually the Senate — their grip on the House actually slipped, as Republican gains meant the Democrats’ majority fell from a 32-seat advantage1 to just a 9-seat edge after the election.   How the Georgia runoffs changed the ‘polling is broken’ narrative   All VideosYouTube   So what happened? Were the polls just terribly off in 2020? Not dramatically, no. Yes, polls once again underestimated Donald Trump’s performance, but the magnitude of that error (about 4 percentage points) wasn’t all that different from past presidential contests, such as in 2012 when polls underestimated Barack Obama’s margin of victory by almost 4 points. And there have, of course, been much larger polling errors, too. [Where Did All The Bellwether Counties Go?] But one reason the polling in 2020 has received so much attention is that down-ballot polling, namely the generic ballot — which asks respondents whether they plan to vote for a Democrat or Republican in their local race for the U.S. House of Representatives — was also off by a similarly large margin in 2020. In fact, as the table below shows, the House popular vote was 4.2 points more Republican-leaning than the polls anticipated, making it the largest generic ballot polling miss in a presidential or midterm cycle since 2006.2 The generic ballot was off significantly in 2020 FiveThirtyEight’s historical generic ballot polling average on Election Day vs. the actual national popular vote for the U.S. House of Representatives, 1996 to 2020  National House vote margin  Year Poll Avg. Actual result Error 2020 D+7.3 D+3.1 4.2 2018 D+8.6 D+8.6 0.0 2016 D+1.3 R+1.0 2.4 2014 R+1.9 R+5.8 3.9 2012 D+2.5 D+1.3 1.2 2010 R+6.7 R+6.6 0.1 2008 D+8.8 D+10.6 1.8 2006 D+13.9 D+7.9 6.0 2004 D+1.2 R+2.6 3.9 2002 R+0.2 R+4.6 4.4 2000 D+3.2 R+0.3 3.6 1998 R+0.2 R+0.9 0.7 1996 D+5.4 D+0.3 5.1 Average   2.9 FiveThirtyEight’s polling averages are calculated retroactively for years prior to 2018. Sources: The Cook Political Report, Polls, U.S. House of Representatives The fact that congressional polls performed so well just two years prior meant the error in 2020 felt particularly large, too. In 2018, the polls nailed the House popular vote right on the head, besting the 2010 midterms for the most accurate cycle in generic ballot polling dating back to 1996. That said, comparing the performance of generic ballot polls in 2020 to 2018 is a bit of a red herring as generic ballot polls are often a better predictor of midterm results than presidential ones: The average error in presidential years was 3.1 points versus 2.5 points in midterms, according to FiveThirtyEight’s polling average. But still, if we look at an average of generic ballot polls from 1996 to 2020 — covering seven presidential elections and six midterms — the polls were only off by 2.9 points. As such, the error in 2020 does rank on the higher end of the spectrum. Nonetheless, it was not the worst performing year for generic ballot polling in the past two and a half decades for which we have data. The polls missed by more in 1996, 2002 and 2006. [Why Only 16 Districts Voted For A Republican And A Democrat In 2020] It’s hard to pinpoint why exactly the generic ballot polls were so off in 2020, but here are some possible explanations. First, it’s possible the 2020 generic ballot polling error was actually pretty normal — that is, generic ballot polls often underestimate GOP support. In the past 13 election cycles, there has been just one time the House vote was clearly more Democratic than the final polling average (and three cases  ...

# %% [markdown]
# ## Extract a list of article titles

# %% [markdown]
# https://fivethirtyeight.com/features/

# %%
url = "https://fivethirtyeight.com/features/"
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")

# %%
h2_list = soup.find_all(name="h2", attrs={"class": "article-title entry-title"})
h2_list
# Out:
# [<h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/democratic-values-are-still-under-attack-even-without-trump-in-the-white-house/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature1">
#  				Democratic Values Are Still Under Attack — Even Without Trump In The White House			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/videos/latino-voters-arent-a-monolith-but-the-gop-made-gains-with-them-just-about-everywhere-in-2020/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature2">
#  				Latino Voters Aren’t A Monolith, But The GOP Made Gains With Them Just About Everywhere In 2020			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/did-psg-really-just-beat-bayern-munich/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature3">
#  				Did PSG Really Just Beat Bayern Munich?			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/can-you-navigate-the-one-way-streets/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature4">
#  				Can You Navigate The One-Way Streets?			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/the-yankees-and-rays-own-the-al-easts-best-rivalry-now/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature5">
#  				The Yankees And Rays Own The AL East’s Best Rivalry Now			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/why-americans-cant-resist-a-celebrity-political-candidate/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature6">
#  				Why Americans Can’t Resist A Celebrity Political Candidate			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/is-soccer-wrong-about-long-shots/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature8">
#  				Is Soccer Wrong About Long Shots?			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/can-new-coaches-and-a-new-vision-fix-michigans-defense/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature9">
#  				Can New Coaches — And A New Vision — Fix Michigan’s Defense?			</a>
#  </h2>, <h2 class="article-title entry-title">
#  <a href="https://fivethirtyeight.com/features/many-democrats-are-sick-of-iowa-and-new-hampshire-going-first-but-the-primary-calendar-is-unlikely-to-change/" name="&amp;lpos=fivethirtyeightFeature&amp;lid=Feature10">
#  				Many Democrats Are Sick Of Iowa And New Hampshire Going First, But The Primary Calendar Is Unlikely To Change			</a>
#  </h2>]

# %% [markdown]
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all

# %% [markdown]
# The <b>find_all</b> method looks through a tag’s descendants and retrieves all descendants that match your filters.

# %%
len(h2_list)
# Out:
# 9

# %%
for h2 in h2_list:
    print(h2.text.strip())
# Out:
# Democratic Values Are Still Under Attack — Even Without Trump In The White House
# Latino Voters Aren’t A Monolith, But The GOP Made Gains With Them Just About Everywhere In 2020
# Did PSG Really Just Beat Bayern Munich?
# Can You Navigate The One-Way Streets?
# The Yankees And Rays Own The AL East’s Best Rivalry Now
# Why Americans Can’t Resist A Celebrity Political Candidate
# Is Soccer Wrong About Long Shots?
# Can New Coaches — And A New Vision — Fix Michigan’s Defense?
# Many Democrats Are Sick Of Iowa And New Hampshire Going First, But The Primary Calendar Is Unlikely To Change

# %%
for h2 in h2_list:
    url = h2.find("a")["href"]     # Starting from each h2 element, go deeper by one level to find an a element 
    print(url)
# Out:
# https://fivethirtyeight.com/features/democratic-values-are-still-under-attack-even-without-trump-in-the-white-house/
# https://fivethirtyeight.com/videos/latino-voters-arent-a-monolith-but-the-gop-made-gains-with-them-just-about-everywhere-in-2020/
# https://fivethirtyeight.com/features/did-psg-really-just-beat-bayern-munich/
# https://fivethirtyeight.com/features/can-you-navigate-the-one-way-streets/
# https://fivethirtyeight.com/features/the-yankees-and-rays-own-the-al-easts-best-rivalry-now/
# https://fivethirtyeight.com/features/why-americans-cant-resist-a-celebrity-political-candidate/
# https://fivethirtyeight.com/features/is-soccer-wrong-about-long-shots/
# https://fivethirtyeight.com/features/can-new-coaches-and-a-new-vision-fix-michigans-defense/
# https://fivethirtyeight.com/features/many-democrats-are-sick-of-iowa-and-new-hampshire-going-first-but-the-primary-calendar-is-unlikely-to-change/

# %% [markdown]
# The hierarchical search of BeautifulSoup is very useful in navigating the nested HTML elements.
